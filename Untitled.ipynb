# %%
import pandas as pd

# Input parameters
#period = input("Enter the period (yyyy-mm): ")
facility_name = input("Enter the facility name: ")
file_path = input("Enter the file path to the Excel file: ")


def load_excel_file(file_path,sheet_name = 'RPTEXT'):
    # Load Excel file
    df = pd.read_excel(file_path,sheet_name)
    
    # Standardize column names: remove leading/trailing spaces and make lowercase
    df.columns = df.columns.str.strip().str.lower()
    print("Standardized column names:", df.columns)
    return df
# Out:
# Enter the facility name:  VHK
# Enter the file path to the Excel file:  /Users/samuelalexander/Downloads/VHK CC Usage Outgoing July 2023.xlsx

# %%
def beneficiation(df, facility_name):
    # Add Facility and Period columns

    df['transaction date'] = pd.to_datetime(df['transaction date'])
    df['facility'] = facility_name
    df['period'] = df['transaction date'].dt.strftime('%Y-%m')

    # Define filter criteria
    filter_types = ['commercial green (more than 1.5 ton)', 'inert waste', 'private green (less than 1.5 ton)']

    # Normalize the waste type column
    df['waste type'] = df['waste type'].str.strip().str.lower()

    # Convert filter_types to lowercase 
    normalized_filter_types = []
    for ft in filter_types:
        normalized_filter_types.append(ft.lower())

    # Debugging: Check data before filtering
    print("Unique waste types in the dataset:", df['waste type'].unique())

    # Filter and retain relevant columns
    filtered_df = df[df['waste type'].isin(normalized_filter_types)]
    print("Filtered data:\n", filtered_df)  # Debugging

    df_ben = filtered_df[['facility', 'period', 'waste type', 'net mass (t)']]
    return df_ben

try:
    # Load the Excel file
    df = load_excel_file(file_path)

    # Apply the beneficiation function
    df_ben = beneficiation(df, facility_name)

    # Print the head of the processed DataFrame
    print("Processed DataFrame:")
    print(df_ben.head())
    print("Net mass sum:",df_ben['net mass (t)'].sum())

except Exception as e:
    print(f"Error: {e}")
# Out:
# Standardized column names: Index(['registration number', 'transaction date', 'transaction time',
#        'card number', 'contract account/costcentre', 'total netmass(kg)',
#        'billed units', 'revenue', 'reference number', 'waste type',
#        'waste category code', 'customer reference number', 'facility code',
#        'payment type', 'business partner', 'total in wb mass(kg)',
#        'total out wb mass(kg)', 'vehicle type', 'net mass (t)'],
#       dtype='object')
# Unique waste types in the dataset: ['commercial green (more than 1.5 ton)']
# Filtered data:
#     registration number transaction date transaction time  card number  \
# 0            CAA120238       2023-07-21         12:17:25            0
# 1            CAA120238       2023-07-21         15:22:16            0
# 2            CAA120238       2023-07-28         07:57:35            0
# 3            CAA120238       2023-07-28         11:12:41            0
# 4            CAA120238       2023-07-28         14:26:22            0
# 5            CAA120238       2023-07-29         10:34:05            0
# 6            CAA120238       2023-07-29         13:09:06            0
# 7            CAA147978       2023-07-21         07:39:14            0
# 8            CAA147978       2023-07-21         12:31:09            0
# 9            CAA147978       2023-07-21         15:24:06            0
# 10           CAA147978       2023-07-27         12:33:40            0
# 11           CAA147978       2023-07-29         08:10:58            0
# 12           CAA147978       2023-07-29         11:04:02            0
# 13           CAA147986       2023-07-26         07:58:58            0
# 14           CAA147986       2023-07-26         11:07:14            0
# 15           CAA147986       2023-07-26         13:47:55            0
# 16           CAA147986       2023-07-27         08:17:53            0
# 17           CAA147986       2023-07-27         11:10:09            0
# 18           CAA147986       2023-07-27         14:20:24            0
# 19           CAA147986       2023-07-29         08:24:15            0
# 20           CAA147986       2023-07-29         11:41:19            0
# 21           CAA147986       2023-07-31         09:05:40            0
# 22           CAA147986       2023-07-31         12:06:54            0
#
#    contract account/costcentre  total netmass(kg)  billed units  revenue  \
# 0         VHKB143                           21620             0        0
# 1         VHKB143                           20760             0        0
# 2         VHKB143                           18520             0        0
# 3         VHKB143                           19180             0        0
# 4         VHKB143                           20560             0        0
# 5         VHKB143                           26980             0        0
# 6         VHKB143                           23420             0        0
# 7         VHKB143                           17900             0        0
# 8         VHKB143                           21020             0        0
# 9         VHKB143                           20180             0        0
# 10        VHKB143                           20420             0        0
# 11        VHKB143                           24060             0        0
# 12        VHKB143                           21540             0        0
# 13        VHKB143                           13740             0        0
# 14        VHKB143                           18060             0        0
# 15        VHKB143                           15600             0        0
# 16        VHKB143                           15380             0        0
# 17        VHKB143                           16340             0        0
# 18        VHKB143                           16040             0        0
# 19        VHKB143                           18400             0        0
# 20        VHKB143                           19440             0        0
# 21        VHKB143                           18440             0        0
# 22        VHKB143                           19960             0        0
#
#         reference number                            waste type  ...  \
# 0   VHKC990               commercial green (more than 1.5 ton)  ...
# 1   VHKC992               commercial green (more than 1.5 ton)  ...
# 2   VHKC1001              commercial green (more than 1.5 ton)  ...
# 3   VHKC1002              commercial green (more than 1.5 ton)  ...
# 4   VHKC1003              commercial green (more than 1.5 ton)  ...
# 5   VHKC1007              commercial green (more than 1.5 ton)  ...
# 6   VHKC1010              commercial green (more than 1.5 ton)  ...
# 7   VHKC989               commercial green (more than 1.5 ton)  ...
# 8   VHKC991               commercial green (more than 1.5 ton)  ...
# 9   VHKC993               commercial green (more than 1.5 ton)  ...
# 10  VHKC999               commercial green (more than 1.5 ton)  ...
# 11  VHKC1004              commercial green (more than 1.5 ton)  ...
# 12  VHKC1008              commercial green (more than 1.5 ton)  ...
# 13  VHKC994               commercial green (more than 1.5 ton)  ...
# 14  VHKC995               commercial green (more than 1.5 ton)  ...
# 15  VHKC1017              commercial green (more than 1.5 ton)  ...
# 16  VHKC997               commercial green (more than 1.5 ton)  ...
# 17  VHKC998               commercial green (more than 1.5 ton)  ...
# 18  VHKC1000              commercial green (more than 1.5 ton)  ...
# 19  VHKC1006              commercial green (more than 1.5 ton)  ...
# 20  VHKC1009              commercial green (more than 1.5 ton)  ...
# 21  VHKC1011              commercial green (more than 1.5 ton)  ...
# 22  VHKC1013              commercial green (more than 1.5 ton)  ...
#
#    customer reference number  facility code payment type  \
# 0                     174878            VHK
# 1                     174880            VHK
# 2                     174910            VHK
# 3                     174912            VHK
# 4                     174914            VHK
# 5                     174918            VHK
# 6                     174920            VHK
# 7                     165051            VHK
# 8                     165053            VHK
# 9                     165055            VHK
# 10                    165091            VHK
# 11                     26553            VHK
# 12                     26555            VHK
# 13                    164907            VHK
# 14                    164909            VHK
# 15                    164911            VHK
# 16                    164914            VHK
# 17                    164916            VHK
# 18                    164918            VHK
# 19                    164926            VHK
# 20                    164927            VHK
# 21                    164930            VHK
# 22                    164932            VHK
#
#                             business partner total in wb mass(kg)  \
# 0   PRIVATE                                                     0
# 1   PRIVATE                                                     0
# 2   PRIVATE                                                     0
# 3   PRIVATE                                                     0
# 4   PRIVATE                                                     0
# 5   PRIVATE                                                     0
# 6   PRIVATE                                                     0
# 7   PRIVATE                                                     0
# 8   PRIVATE                                                     0
# 9   PRIVATE                                                     0
# 10  PRIVATE                                                     0
# 11  PRIVATE                                                     0
# 12  PRIVATE                                                     0
# 13  PRIVATE                                                     0
# 14  PRIVATE                                                     0
# 15  PRIVATE                                                     0
# 16  PRIVATE                                                     0
# 17  PRIVATE                                                     0
# 18  PRIVATE                                                     0
# 19  PRIVATE                                                     0
# 20  PRIVATE                                                     0
# 21  PRIVATE                                                     0
# 22  PRIVATE                                                     0
#
#     total out wb mass(kg)     vehicle type net mass (t)  facility   period
# 0                       0  T/RoRo/Skip 6x4        21.62       VHK  2023-07
# 1                       0  T/RoRo/Skip 6x4        20.76       VHK  2023-07
# 2                       0  T/RoRo/Skip 6x4        18.52       VHK  2023-07
# 3                       0  T/RoRo/Skip 6x4        19.18       VHK  2023-07
# 4                       0  T/RoRo/Skip 6x4        20.56       VHK  2023-07
# 5                       0  T/RoRo/Skip 6x4        26.98       VHK  2023-07
# 6                       0  T/RoRo/Skip 6x4        23.42       VHK  2023-07
# 7                       0  T/RoRo/Skip 6x4        17.90       VHK  2023-07
# 8                       0  T/RoRo/Skip 6x4        21.02       VHK  2023-07
# 9                       0  T/RoRo/Skip 6x4        20.18       VHK  2023-07
# 10                      0  T/RoRo/Skip 6x4        20.42       VHK  2023-07
# 11                      0  T/RoRo/Skip 6x4        24.06       VHK  2023-07
# 12                      0  T/RoRo/Skip 6x4        21.54       VHK  2023-07
# 13                      0  T/RoRo/Skip 6x4        13.74       VHK  2023-07
# 14                      0  T/RoRo/Skip 6x4        18.06       VHK  2023-07
# 15                      0  T/RoRo/Skip 6x4        15.60       VHK  2023-07
# 16                      0  T/RoRo/Skip 6x4        15.38       VHK  2023-07
# 17                      0  T/RoRo/Skip 6x4        16.34       VHK  2023-07
# 18                      0  T/RoRo/Skip 6x4        16.04       VHK  2023-07
# 19                      0  T/RoRo/Skip 6x4        18.40       VHK  2023-07
# 20                      0  T/RoRo/Skip 6x4        19.44       VHK  2023-07
# 21                      0  T/RoRo/Skip 6x4        18.44       VHK  2023-07
# 22                      0  T/RoRo/Skip 6x4        19.96       VHK  2023-07
#
# [23 rows x 21 columns]
# Processed DataFrame:
#   facility   period                            waste type  net mass (t)
# 0      VHK  2023-07  commercial green (more than 1.5 ton)         21.62
# 1      VHK  2023-07  commercial green (more than 1.5 ton)         20.76
# 2      VHK  2023-07  commercial green (more than 1.5 ton)         18.52
# 3      VHK  2023-07  commercial green (more than 1.5 ton)         19.18
# 4      VHK  2023-07  commercial green (more than 1.5 ton)         20.56
# Net mass sum: 447.55999999999995

# %%
this is tthhh
